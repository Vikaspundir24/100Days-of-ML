# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
#STEPS

#0. preprocess + EDA (Exploratory data analysis) + Feature Selection
#1. Extract input and output cols
#2. Scale the values
#3. Train test split
#4. Train the model
#5. Evaluate the model/ model selection
#6. Deploy the model

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'], c = df['placement'])

# %%
X = df.iloc[:,0:2]
Y = df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
Y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 75   4.8  169.0
# 84   5.7  169.0
# 17   3.3  183.0
# 48   6.6  138.0
# 30   7.6  128.0
# ..   ...    ...
# 27   6.0  124.0
# 1    5.9  106.0
# 11   6.9  138.0
# 29   7.0  112.0
# 62   6.0  102.0
#
# [90 rows x 2 columns]

# %%
Y_train
# Out:
# 75    0
# 84    0
# 17    0
# 48    1
# 30    1
#      ..
# 27    1
# 1     0
# 11    1
# 29    1
# 62    0
# Name: placement, Length: 90, dtype: int64

# %%
X_test
# Out:
#     cgpa     iq
# 96   4.4   42.0
# 24   4.7  121.0
# 55   7.8  114.0
# 12   5.4  139.0
# 60   6.9  139.0
# 4    5.8  142.0
# 89   4.9  151.0
# 77   7.3   50.0
# 8    6.1  156.0
# 70   6.3  127.0

# %%
X_test
# Out:
#     cgpa     iq
# 96   4.4   42.0
# 24   4.7  121.0
# 55   7.8  114.0
# 12   5.4  139.0
# 60   6.9  139.0
# 4    5.8  142.0
# 89   4.9  151.0
# 77   7.3   50.0
# 8    6.1  156.0
# 70   6.3  127.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-1.04409044,  1.12368604],
#        [-0.25738043,  1.12368604],
#        [-2.35527378,  1.47475086],
#        [ 0.52932957,  0.34632823],
#        [ 1.4034518 ,  0.09556765],
#        [ 0.09226846, -1.48422404],
#        [-1.74338822, -1.23346345],
#        [-1.04409044,  0.97322969],
#        [-1.48115156,  1.90104385],
#        [ 0.35450513, -0.20534506],
#        [-0.95667822,  0.246024  ],
#        [ 0.52932957, -0.10504082],
#        [-0.25738043,  0.39648035],
#        [ 2.19016181, -0.10504082],
#        [ 0.17968068, -0.28057323],
#        [-0.78185377,  1.29921845],
#        [ 0.87897846,  1.8759678 ],
#        [ 1.4034518 , -0.88239863],
#        [-0.86926599, -0.83224652],
#        [ 0.6167418 ,  1.4496748 ],
#        [ 0.44191735, -0.85732258],
#        [ 0.87897846,  0.37140429],
#        [ 0.35450513,  0.42155641],
#        [-0.86926599, -1.53437615],
#        [-1.13150266, -1.8102128 ],
#        [ 0.79156624, -0.70686623],
#        [-0.5196171 , -0.25549717],
#        [ 1.84051292,  0.62216487],
#        [-1.04409044,  0.42155641],
#        [ 0.87897846,  1.27414239],
#        [ 0.00485623, -1.45914798],
#        [-0.69444155,  0.92307757],
#        [ 0.2670929 ,  0.09556765],
#        [-0.25738043,  0.47170852],
#        [-1.04409044, -0.30564929],
#        [ 0.09226846,  0.19587188],
#        [-0.60702933, -0.25549717],
#        [-0.69444155,  2.50286926],
#        [ 1.31603958, -1.58452827],
#        [ 0.00485623, -1.98574521],
#        [-2.18044934,  2.72855378],
#        [ 0.70415402, -0.02981265],
#        [-0.5196171 ,  0.27110005],
#        [ 0.87897846, -1.5093001 ],
#        [-0.95667822,  1.80073962],
#        [ 1.75310069, -1.13315922],
#        [ 0.70415402, -0.30564929],
#        [ 1.84051292,  1.04845787],
#        [-0.69444155,  0.19587188],
#        [ 0.96639069, -1.91051703],
#        [-1.21891489,  0.5469367 ],
#        [ 0.70415402, -0.85732258],
#        [-0.95667822, -0.10504082],
#        [ 1.14121513, -0.20534506],
#        [-0.69444155, -0.35580141],
#        [-0.69444155, -0.85732258],
#        [-0.86926599, -0.15519294],
#        [-0.78185377, -1.45914798],
#        [ 0.44191735,  0.89800152],
#        [-0.78185377,  0.09556765],
#        [ 0.44191735, -2.18635367],
#        [-0.25738043,  0.19587188],
#        [ 0.2670929 , -0.53133382],
#        [-0.95667822,  0.77262122],
#        [ 0.09226846, -0.53133382],
#        [ 0.44191735,  0.14571976],
#        [-1.83080045, -0.38087747],
#        [ 0.70415402,  0.42155641],
#        [ 1.22862736,  0.19587188],
#        [-0.95667822, -1.58452827],
#        [-1.74338822, -0.60656199],
#        [-0.5196171 , -0.43102958],
#        [ 1.31603958,  0.8478494 ],
#        [ 0.6167418 ,  0.74754517],
#        [ 1.14121513, -0.95762681],
#        [ 0.09226846, -1.0830071 ],
#        [-0.60702933, -0.07996476],
#        [-0.16996821,  1.04845787],
#        [-1.39373933,  0.62216487],
#        [ 0.96639069,  0.67231699],
#        [ 2.01533736,  1.09860998],
#        [-1.13150266, -0.93255075],
#        [ 1.31603958,  0.14571976],
#        [ 0.00485623,  0.62216487],
#        [ 1.14121513,  0.32125217],
#        [ 0.00485623, -0.00473659],
#        [-0.08255599, -0.45610564],
#        [ 0.79156624,  0.34632823],
#        [ 0.87897846, -0.30564929],
#        [ 0.00485623, -0.55640987]])

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-1.39373933, -2.06097338],
#        [-1.13150266, -0.07996476],
#        [ 1.57827625, -0.25549717],
#        [-0.5196171 ,  0.37140429],
#        [ 0.79156624,  0.37140429],
#        [-0.16996821,  0.44663246],
#        [-0.95667822,  0.67231699],
#        [ 1.14121513, -1.86036491],
#        [ 0.09226846,  0.79769728],
#        [ 0.2670929 ,  0.07049159]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
#model training
clf.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
Y_pred = clf.predict(X_test)
Y_pred
# Out:
# array([0, 0, 1, 0, 1, 0, 0, 1, 1, 1])

# %%
Y_test
# Out:
# 96    0
# 24    0
# 55    1
# 12    0
# 60    1
# 4     0
# 89    0
# 77    1
# 8     0
# 70    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_test,Y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, Y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl' , 'wb'))

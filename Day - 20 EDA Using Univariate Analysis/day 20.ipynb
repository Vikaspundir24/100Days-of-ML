# %% [markdown]
# # UNIVARIATE ANALYSIS -  HAR COLUMN KO INDEPENDENT ANALYSIS and COLUMN data is either NUMERICAL or CATEGORICAL

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # 1. Categorical Data

# %% [markdown]
# ## a.CountPlot

# %%
sns.countplot(x  = 'Survived', data = df,palette='Set1', hue='Survived')
#df['Survived'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x  = 'Sex', data = df, palette='Set1', hue='Sex')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x  = 'Pclass', data = df,palette='Set1', hue='Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(data = df, x = 'Embarked', palette = 'Set1', hue = 'Embarked')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# ## b. PieChart

# %%
df['Survived'].value_counts().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # 2. Numerical Data

# %% [markdown]
# ## a. Histogram

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Age'], bins = 10)
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## b. DistPlot

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\vikas\AppData\Local\Temp\ipykernel_27088\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## c. BoxPlot -  Noisy DATA identification

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['Age'].std()
# Out:
# 14.526497332334044

# %%
df['Age'].skew()
# Out:
# np.float64(0.38910778230082704)
